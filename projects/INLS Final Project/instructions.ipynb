# %% [markdown]
# ### Instructions

# %% [markdown]
# Do not run any Acquire and Prepare. This file will take hours to run. Simply run the other 2 files for the analysis. The order does not matter but start either from top to bottom.
